# %% [markdown]
# # Paths

# %%
path = '/home/tih_isi_7/G-NeuroDAVIS/'
res_plots = path + 'Results/Plots/'
res_model = path + 'Results/Models/'
path_emb = path + 'Data/Embeddings/'

# %% [markdown]
# # Importing libraries

# %%
import sys
sys.path.append(path)

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import keras
import ipynbname
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import Datasets as ds
from keras.models import load_model
from utils import DownstreamAnalysis as DA

dataname = ipynbname.name().rsplit("_")[0]
txt = %pwd
methodname = txt.rsplit("/")[-1]

# %% [markdown]
# # Load Models

# %%
y, _ = ds.LoadData(dataname, DType='None', LType=True)
x_embedding = np.array(pd.read_csv(path_emb+dataname+'/'+dataname+'_'+methodname+'.csv', index_col=0, header=0))
model_decoder = load_model(res_model+dataname+'/'+dataname+'_'+methodname+'_decoder.keras')

# %% [markdown]
# # Plots

# %%
DA.plot_latent_space(model_decoder, x_embedding=x_embedding, digit_size = 28, dataname=dataname,
                      methodname="G-NeuroDAVIS (Unsupervised) ", res_plots=res_plots)

# %%
DA.generate(model_decoder, x_embedding, dataname=dataname, methodname=methodname, res_plots=res_plots)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
plt.style.use('ggplot')
plt.figure(figsize=(4, 4))
sc = plt.scatter(x_embedding[:, 0], x_embedding[:, 1], c=y, s=1, cmap='gist_ncar')
plt.xlabel("G-NeuroDAVIS1")
plt.ylabel("G-NeuroDAVIS2")
plt.xticks([])
plt.yticks([])
plt.legend(handles=sc.legend_elements()[0], labels=list(np.unique(y)),
                             ncol=1, bbox_to_anchor = (1.,0.85))
newpath = res_plots+dataname+'/'
if not os.path.exists(newpath):
    os.makedirs(newpath)
plt.savefig(newpath+dataname+'_'+methodname+'_embedding.pdf')
plt.show()
